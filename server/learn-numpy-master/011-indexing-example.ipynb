# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Displaying a 2d array as an image

# %% [markdown]
# ## Monochrome

# %%
m = np.random.randint(0, 2, (5,5), dtype=bool)
m
# Out:
# array([[ True, False, False, False,  True],
#        [False,  True,  True,  True, False],
#        [False, False,  True,  True,  True],
#        [ True, False,  True, False, False],
#        [False, False,  True, False,  True]])

# %%
plt.imshow(m);

# %% [markdown]
# ## Scalar data, Normalized

# %%
a = np.arange(100).reshape(10, 10)

# %%
a[9][9] = 0

# %%
plt.imshow(a);

# %%
plt.imshow(a)
plt.colorbar();

# %%
plt.imshow(a, 'gray')
plt.colorbar();

# %%
plt.imshow(a, 'Reds')
plt.colorbar();

# %%
plt.imshow(a, plt.cm.Reds)
plt.colorbar();

# %% [markdown]
# Matplotlib colormaps: <https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html>

# %%
print(" ".join(plt.cm.cmap_d))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(" ".join(plt.cm.cmap_d))
#
# AttributeError: module 'matplotlib.cm' has no attribute 'cmap_d'

# %%
cmap = plt.cm.get_cmap("Spectral")
cmap
# Out:
# C:\Users\208563197\AppData\Local\Temp\ipykernel_20296\491857890.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("Spectral")

# %% [markdown]
# ## Indexing Example: RGB data

# %%
m = np.random.random((150, 200, 3))

# %%
m
# Out:
# array([[[0.03585924, 0.96504549, 0.53379951],
#         [0.04831726, 0.35086415, 0.83551365],
#         [0.02698891, 0.9023193 , 0.71315579],
#         ...,
#         [0.60530723, 0.18074674, 0.05285156],
#         [0.26089424, 0.73168396, 0.33011852],
#         [0.15385074, 0.49748782, 0.23462842]],
#
#        [[0.33735832, 0.53112831, 0.87339749],
#         [0.79206161, 0.40662521, 0.21720262],
#         [0.00398482, 0.64203577, 0.9801074 ],
#         ...,
#         [0.45304726, 0.51196495, 0.99331425],
#         [0.49374442, 0.92557705, 0.27053319],
#         [0.73702265, 0.30681269, 0.71127551]],
#
#        [[0.9870351 , 0.19940055, 0.4358593 ],
#         [0.71644545, 0.68168589, 0.6237478 ],
#         [0.2787078 , 0.75232899, 0.18380033],
#         ...,
#         [0.18012309, 0.8513866 , 0.87848255],
#         [0.96266565, 0.8657408 , 0.35248766],
#         [0.41471253, 0.10388658, 0.6751915 ]],
#
#        ...,
#
#        [[0.9083491 , 0.18748878, 0.56776817],
#         [0.43533429, 0.70208182, 0.69579537],
#         [0.75101802, 0.03408676, 0.69601887],
#         ...,
#         [0.41420346, 0.39595697, 0.83962835],
#         [0.49243186, 0.69902217, 0.04766935],
#         [0.55775886, 0.00484376, 0.111691  ]],
#
#        [[0.42020415, 0.90597262, 0.66819178],
#         [0.59354638, 0.54751936, 0.39957787],
#         [0.66045474, 0.18089911, 0.11714725],
#         ...,
#         [0.44499602, 0.39165045, 0.94102333],
#         [0.72150798, 0.40641755, 0.0882584 ],
#         [0.27850267, 0.06680439, 0.03787781]],
#
#        [[0.54796942, 0.62735803, 0.51926753],
#         [0.92910471, 0.62807414, 0.30036869],
#         [0.4080497 , 0.74954516, 0.62552355],
#         ...,
#         [0.07339016, 0.61426318, 0.09189088],
#         [0.07405028, 0.78940802, 0.68534909],
#         [0.60852467, 0.03287269, 0.40735815]]])

# %%
plt.imshow(m);

# %%
m[61, 110] # one pixel
# Out:
# array([0.54600594, 0.60724603, 0.83677215])

# %%
m[25:30, 100:104] # a 5x4x3 view
# Out:
# array([[[0.27399214, 0.35264725, 0.47850003],
#         [0.68170829, 0.15907981, 0.3709125 ],
#         [0.05135637, 0.11114817, 0.24610661],
#         [0.28105779, 0.54009917, 0.88073795]],
#
#        [[0.76370787, 0.9320131 , 0.39826729],
#         [0.78749759, 0.0985188 , 0.11607584],
#         [0.6516483 , 0.17469277, 0.34116729],
#         [0.35831296, 0.31320222, 0.41332965]],
#
#        [[0.97927862, 0.80390765, 0.49204772],
#         [0.78666152, 0.68414823, 0.43961253],
#         [0.46591178, 0.82867541, 0.66913863],
#         [0.79004218, 0.02903529, 0.90227566]],
#
#        [[0.79617752, 0.6857217 , 0.01733052],
#         [0.3483478 , 0.82167793, 0.27039006],
#         [0.84318658, 0.66207007, 0.60473319],
#         [0.02396196, 0.55459071, 0.15176237]],
#
#        [[0.72159508, 0.67484629, 0.19649353],
#         [0.50011043, 0.33314209, 0.30888804],
#         [0.9417526 , 0.50130836, 0.6671036 ],
#         [0.58594779, 0.15632517, 0.79405017]]])

# %%
m[:,:,0] # The R channel, 150x200 view
# Out:
# array([[0.03585924, 0.04831726, 0.02698891, ..., 0.60530723, 0.26089424,
#         0.15385074],
#        [0.33735832, 0.79206161, 0.00398482, ..., 0.45304726, 0.49374442,
#         0.73702265],
#        [0.9870351 , 0.71644545, 0.2787078 , ..., 0.18012309, 0.96266565,
#         0.41471253],
#        ...,
#        [0.9083491 , 0.43533429, 0.75101802, ..., 0.41420346, 0.49243186,
#         0.55775886],
#        [0.42020415, 0.59354638, 0.66045474, ..., 0.44499602, 0.72150798,
#         0.27850267],
#        [0.54796942, 0.92910471, 0.4080497 , ..., 0.07339016, 0.07405028,
#         0.60852467]])

# %%
plt.imshow(m[:,:,0], vmin=0, vmax=1)
plt.colorbar();

# %%
plt.imshow(m[:,0,:], 'gray', vmin=0, vmax=1)
plt.colorbar();
